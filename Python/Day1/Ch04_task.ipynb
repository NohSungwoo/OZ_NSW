# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```다음 중 14 % 3의 계산 결과로 옳은 것을 고르세요```
#
# 1. 4
# 2. 4.6
# 3. 2
# 4. 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3번
# 풀이 : %는 나머지를 구하는 연산자이기 때문에
# 14 / 3 = 4 ... 2
# 답은 2

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```다음 중 올바르지 않은 것을 고르세요```
#
# 1. float(17//3)
# 2. int(10)-9
# 3. float11/2
# 4. float(10)-2

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3번
# 풀이 : 문법 오류 float(11) / 2 or float(11 / 2)로 ()를 사용해 줘야 한다.

# %% [markdown]
# ----

# %% [markdown]
# [문제3]<br><br>
# 다음 계산식의 결괏값을 골라주세요
#
# (3 * 7 - 16) / 2 - 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1.5
# 풀이 : 사칙연산에 의거해 괄호 안의 값을 먼저 구한다.
# 5 / 2 - 1
# 이 때 "/" 기호는 답을 float로 반환하기 때문에
# 2.5 - 1은
# 1.5 float 자료형으로 답이 나온다.

# %% [markdown]
# ----

# %% [markdown]
# [문제4]<br><br>
# 거듭제곱을 올바르게 표현한 식을 골라주세요
#
# 1. 2 ^^ 3
# 2. 2 ** 3
# 3. 2 ^* 3
# 4. 2 ~~ 3

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2번
# 풀이 : 곱셈은 * 거듭제곱은 **

# %% [markdown]
# ----

# %% [markdown]
# [문제5]<br><br>
# 목과 나머지를 함께 구하기 위해 사용할 수 있는 표현을 골라주세요
#
# 1. //
# 2. divmod()
# 3. %
# 4. /

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2번
# 풀이 : divmod()함수를 사용하면 전달받은 인자의 몫과 나머지를 구해준다.
# divmod(a, b)
