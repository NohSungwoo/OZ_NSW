# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
# 1. 결측치가 있는 행을 모두 제거하세요.
iris = iris.dropna(inplace = True)
iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-bdd20c5b94f9> in <cell line: 2>()
#       1 # 1. 결측치가 있는 행을 모두 제거하세요.
# ----> 2 iris = iris.dropna(inplace = True)
#       3 iris
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
# 2. 중복된 행을 제거하세요.
iris.drop_duplicates(inplace = True)
iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-3e267a952033> in <cell line: 2>()
#       1 # 2. 중복된 행을 제거하세요.
# ----> 2 iris.drop_duplicates(inplace = True)
#       3 iris
#
# AttributeError: 'NoneType' object has no attribute 'drop_duplicates'

# %%
# 3. 'petal_length'가 5보다 큰 행만 선택하세요.
filtered_iris = iris[iris['petal_length'] > 5]
iris
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eb0cbebf51ad> in <cell line: 2>()
#       1 # 3. 'petal_length'가 5보다 큰 행만 선택하세요.
# ----> 2 filtered_iris = iris[iris['petal_length'] > 5]
#       3 iris
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 4. 'species'에 따라 데이터를 그룹화하세요.
grouped_iris = iris.groupby('species')
iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-f63d3fa0653a> in <cell line: 2>()
#       1 # 4. 'species'에 따라 데이터를 그룹화하세요.
# ----> 2 grouped_iris = iris.groupby('species')
#       3 iris
#
# AttributeError: 'NoneType' object has no attribute 'groupby'

# %%
# 5. 그룹화한 데이터에서 'sepal_length'의 평균을 계산하세요.
mean_sepal_length = grouped_iris['sepla_length'].mean()
iris
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b0259f4aad70> in <cell line: 2>()
#       1 # 5. 그룹화한 데이터에서 'sepal_length'의 평균을 계산하세요.
# ----> 2 mean_sepal_length = grouped_iris['sepla_length'].mean()
#       3 iris
#
# NameError: name 'grouped_iris' is not defined

# %%
# 6. 'petal_length'를 기준으로 데이터를 오름차순으로 정렬하세요.
iris.sort_values('petal_length', inplace = True)
iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-cd2b76718d63> in <cell line: 2>()
#       1 # 6. 'petal_length'를 기준으로 데이터를 오름차순으로 정렬하세요.
# ----> 2 iris.sort_values('petal_length', inplace = True)
#       3 iris
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
# 7. 'petal_width'를 기준으로 데이터를 내림차순으로 정렬하세요.
iris.sort_values('petal_width', ascending = False, inplace = True)
iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-f70082fed822> in <cell line: 2>()
#       1 # 7. 'petal_width'를 기준으로 데이터를 내림차순으로 정렬하세요.
# ----> 2 iris.sort_values('petal_width', ascending = False, inplace = True)
#       3 iris
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
# 8. 'species'의 빈도수를 구하세요.
print(iris['species'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3fb63c75bdee> in <cell line: 2>()
#       1 # 8. 'species'의 빈도수를 구하세요.
# ----> 2 print(iris['species'].value_counts())
#       3
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#9. 'species'값 중 'setosa'를 포함하는 행만 선택하세요.
setosa_rows = iris[iris['species'].str.contains('setosa')]
setosa_rows
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6ddbd2d64669> in <cell line: 2>()
#       1 #9. 'species'값 중 'setosa'를 포함하는 행만 선택하세요.
# ----> 2 setosa_rows = iris[iris['species'].str.contains('setosa')]
#       3 setosa_rows
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 10. 'species' 값이 'setosa'로 시작하는 행을 선택하세요.
setosa_start = iris[iris['species'].str.startswith('setosa')]
setosa_start
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-643cae763def> in <cell line: 2>()
#       1 # 10. 'species' 값이 'setosa'로 시작하는 행을 선택하세요.
# ----> 2 setosa_start = iris[iris['species'].str.startswith('setosa')]
#       3 setosa_start
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 11. 'species' 값이 'virginica'로 끝나느 행을 선택하세요.
virginica_end = iris[iris['species'].str.endswith('virginica')]
virginica_end
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-449fb36156af> in <cell line: 2>()
#       1 # 11. 'species' 값이 'virginica'로 끝나느 행을 선택하세요.
# ----> 2 virginica_end = iris[iris['species'].str.endswith('virginica')]
#       3 virginica_end
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 12. 'species'의 'setosa'를 'SETOSA'로 대체하세요.
iris['species'] = iris['species'].replace('setosa', 'SETOSA')
iris
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-deaeb4cf112e> in <cell line: 2>()
#       1 # 12. 'species'의 'setosa'를 'SETOSA'로 대체하세요.
# ----> 2 iris['species'] = iris['species'].replace('setosa', 'SETOSA')
#       3 iris
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 13. iris 데이터셋에서 'species'열을 제거하세요.
iris.drop('species', axis = 1, inplace = True)
iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-5d54962e17fd> in <cell line: 2>()
#       1 # 13. iris 데이터셋에서 'species'열을 제거하세요.
# ----> 2 iris.drop('species', axis = 1, inplace = True)
#       3 iris
#
# AttributeError: 'NoneType' object has no attribute 'drop'
